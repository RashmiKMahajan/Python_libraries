# %% [markdown]
# Name : Rashmi Mahajan
# Batch : Data science Masters
# Topic : Matplotlib
# Date : 2/3/2023

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a popular data visualization library in Python. It provides a wide range of tools to create static, animated, and interactive plots in Python. Matplotlib is widely used for visualizing data in the fields of science, engineering, finance, and many others.
#
# Some of the reasons why Matplotlib is used are:
#
# It is a powerful and flexible library that provides a wide range of visualization options.
# It is easy to learn and use.
# It integrates well with other scientific computing libraries in Python such as NumPy, Pandas, and Scikit-Learn.
# It has a large and active community, which means that there are many resources and examples available online.
# Five plots that can be plotted using the Pyplot module of Matplotlib are:
#
# Line Plot:
# A line plot is a type of plot that displays data as a series of points connected by straight lines.
#
# Scatter Plot:
# A scatter plot is a type of plot that displays data as a collection of points.
#
# Histogram:
# A histogram is a type of plot that displays the distribution of a dataset.
#
# Bar Plot:
# A bar plot is a type of plot that displays the frequency or distribution of categorical data.
#
# Box Plot:
# A box plot is a type of plot that displays the distribution of a dataset based on the five-number summary (minimum, first quartile, median, third quartile, and maximum).

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [raw]
# Scatter plot :
# a graph in which the values of two variables are plotted along two axes, the pattern of the resulting points revealing any correlation present.

# %%
import numpy as np

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

# %%
x
# Out:
# array([ 6.57725695,  3.8730197 ,  3.19299494, -0.72698541,  2.44522359,
#         2.29048204,  2.83451704,  1.74599865,  2.91236366,  2.04556394,
#         0.37227049,  4.76924476,  4.76263608,  6.41914613,  3.10006728,
#         2.19064517,  1.9092801 , -0.09295463,  4.96473487,  0.79786474,
#         0.62990695,  2.5887002 ,  5.97229671,  3.47343253,  0.95242972,
#         1.5740136 ,  4.25048993,  2.67897327,  1.4623273 ,  2.53993856,
#         4.49011253,  6.95222157,  0.51175334,  1.74716618,  1.39246781,
#        -1.83816635,  1.15241596,  0.95224848,  5.24795592,  2.73617153,
#        -0.24657089,  4.2933509 ,  2.28745848, -0.48628207,  1.80670072,
#         1.82281124,  1.2522354 ,  3.05942763, -1.49651554,  2.46447627])

# %%
y
# Out:
# array([ 5.02636688,  4.70559568,  5.216375  ,  5.23878131,  5.97508626,
#         0.76339863,  4.69166681, -0.72177906,  1.79422979, -0.82894409,
#         5.09629502,  5.66747564,  2.60517064,  6.54929006,  1.65054498,
#         3.30123373,  3.30589141,  0.87160945,  3.87589322,  6.87795692,
#         0.95013825,  4.79867689,  2.6909863 ,  6.53925461,  3.9675767 ,
#         4.3524328 ,  4.28632656,  3.49817341,  0.20847299,  5.78332582,
#         0.25866197,  3.47712638,  4.22815418,  1.32417545,  3.29012643,
#         5.33576457,  2.95179106,  1.22268516, -2.8314755 ,  1.05631899,
#         1.81784252,  1.96716526,  1.08000764,  3.75459047,  1.85058316,
#         2.78109133,  4.3581432 ,  1.28912566,  2.39958785,  7.31629868])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("my title is plotting x vs y")
# Out:
# Text(0.5, 1.0, 'my title is plotting x vs y')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and  y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# pyplot. subplots method provides a way to plot multiple plots on a single figure. Given the number of rows and columns , it returns a tuple ( fig , ax ), giving a single figure fig with an array of axes ax

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

# %%
x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([ 50, 20, 40, 20, 60,70])

# %%
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])

# %%
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
fig,a =  plt.subplots(2,2)
x = np.arange(1,5)
a[0][0].plot(x1,y1)
a[0][0].set_title('x1 vs y1')
a[0][1].plot(x2,y2)
a[0][1].set_title('x2 vs y2')
a[1][0].plot(x3,y3)
a[1][0].set_title('x3 vs y3')
a[1][1].plot(x4,y4)
a[1][1].set_title('x4 vs y4')
plt.show()

# %%
# subplot
ax1 = plt.subplot(1, 1,1)
ax1.plot(x1, y1)
ax1.plot(x2, y2)
ax1.plot(x3, y3)
ax1.plot(x4, y4)
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [raw]
# Bar plots are a type of data visualization used to represent data in the form of rectangular bars. The height of each bar represents the value of a data point, and the width of each bar represents the category of the data.
#
# A bar chart is used when you want to show a distribution of data points or perform a comparison of metric values across different subgroups of your data. From a bar chart, we can see which groups are highest or most common, and how other groups compare against the others.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Company vs Profit")
# Out:
# Text(0.5, 1.0, 'Company vs Profit')

# %%
plt.barh(company,profit)
plt.ylabel("Company")
plt.xlabel("Profit")
plt.title("Company vs Profit")
# Out:
# Text(0.5, 1.0, 'Company vs Profit')

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
data = [box1,box2]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa60cd33eb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa60cbc15d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa60cd32c20>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fa60cbc16c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa60cbc29b0>,
# ...
#  'means': []}
